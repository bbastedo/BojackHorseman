# %% [markdown]
# # Bojack Horeseman and Netflix Stock Prices

# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %% [markdown]
# ### Read *Bojack Horeseman Season 1-5 Release Date and Ratings* CSV

# %%
bojack_csv = os.path.join("..", "Resources", "Bojack_Ratings.csv")
bojack_df = pd.read_csv(bojack_csv)

bojack_df["Release Date"] = bojack_df['AIR MONTH'].map(str) + "/" + bojack_df['AIR DAY'].map(str) + "/" + bojack_df['YEAR'].map(str)

bojack_df.head()
# Out:
#    SEASON  EPISODE  EPISODE TIME (NETFLIX)  RATING (IMDB)  YEAR  AIR MONTH  \
# 0       1        1                   25.38            7.1  2014          8
# 1       1        2                   25.34            7.7  2014          8
# 2       1        3                   25.59            7.4  2014          8
# 3       1        4                   25.36            7.4  2014          8
# 4       1        5                   25.32            7.4  2014          8
#
#    AIR DAY Release Date
# 0       22    8/22/2014
# 1       22    8/22/2014
# 2       22    8/22/2014
# 3       22    8/22/2014
# 4       22    8/22/2014

# %% [markdown]
# ### Read *Netflix* CSV

# %%
netflix_csv = os.path.join("..", "Resources", "NFLX_Stock.csv")
netflix_df = pd.read_csv(netflix_csv)

netflix_df.head()
# Out:
#    year    date     open     high      low    close    volume
# 0  2014  1/2/14  52.4014  52.5114  51.5429  51.8314  12325600
# 1  2014  1/3/14  52.0000  52.4956  51.8429  51.8714  10817100
# 2  2014  1/6/14  51.8900  52.0443  50.4757  51.3671  15501500
# 3  2014  1/7/14  49.6843  49.6986  48.1529  48.5000  36167600
# 4  2014  1/8/14  48.1043  49.4257  48.0743  48.7129  20001100

# %% [markdown]
# ### Parse date from Stock Data in order to accurately query dates for review

# %%
netflix_df['Month']=[int(d.split('/')[0]) for d in netflix_df.date]
netflix_df['Day']=[int(d.split('/')[1]) for d in netflix_df.date]
netflix_df['Year']=[int(d.split('/')[2]) for d in netflix_df.date]

netflix_df.head()
# Out:
#    year    date     open     high      low    close    volume  Month  Day  \
# 0  2014  1/2/14  52.4014  52.5114  51.5429  51.8314  12325600      1    2
# 1  2014  1/3/14  52.0000  52.4956  51.8429  51.8714  10817100      1    3
# 2  2014  1/6/14  51.8900  52.0443  50.4757  51.3671  15501500      1    6
# 3  2014  1/7/14  49.6843  49.6986  48.1529  48.5000  36167600      1    7
# 4  2014  1/8/14  48.1043  49.4257  48.0743  48.7129  20001100      1    8
#
#    Year
# 0    14
# 1    14
# 2    14
# 3    14
# 4    14

# %% [markdown]
# ### Transform Bojack DataFrame

# %%
clean_bojack_df = bojack_df[["SEASON","EPISODE","RATING (IMDB)","YEAR","Release Date"]].copy()

# Rename the column headers
clean_bojack_df = clean_bojack_df.rename(columns={"Season": "SEASON",
                                                    "Episode": "EPISODE",
                                                    "IMDB Rating": "RATING (IMDB)",
                                                    "Year": "YEAR"})
# Display new df
clean_bojack_df.head(100)
# Out:
#     SEASON  EPISODE  RATING (IMDB)  YEAR Release Date
# 0        1        1            7.1  2014    8/22/2014
# 1        1        2            7.7  2014    8/22/2014
# 2        1        3            7.4  2014    8/22/2014
# 3        1        4            7.4  2014    8/22/2014
# 4        1        5            7.4  2014    8/22/2014
# 5        1        6            7.9  2014    8/22/2014
# 6        1        7            8.0  2014    8/22/2014
# 7        1        8            8.2  2014    8/22/2014
# 8        1        9            7.9  2014    8/22/2014
# 9        1       10            7.8  2014    8/22/2014
# 10       1       11            8.6  2014    8/22/2014
# 11       1       12            8.1  2014    8/22/2014
# 12       2        1            8.0  2015    7/17/2015
# 13       2        2            7.9  2015    7/17/2015
# 14       2        3            7.9  2015    7/17/2015
# 15       2        4            8.0  2015    7/17/2015
# 16       2        5            8.0  2015    7/17/2015
# 17       2        6            7.7  2015    7/17/2015
# 18       2        7            8.1  2015    7/17/2015
# 19       2        8            8.2  2015    7/17/2015
# 20       2        9            8.1  2015    7/17/2015
# 21       2       10            8.2  2015    7/17/2015
# 22       2       11            8.7  2015    7/17/2015
# 23       2       12            8.1  2015    7/17/2015
# 24       3        1            7.9  2016    7/22/2016
# 25       3        2            8.0  2016    7/22/2016
# 26       3        3            7.4  2016    7/22/2016
# 27       3        4            9.1  2016    7/22/2016
# 28       3        5            8.1  2016    7/22/2016
# 29       3        6            8.0  2016    7/22/2016
# 30       3        7            8.1  2016    7/22/2016
# 31       3        8            7.9  2016    7/22/2016
# 32       3        9            8.1  2016    7/22/2016
# 33       3       10            8.2  2016    7/22/2016
# 34       3       11            9.0  2016    7/22/2016
# 35       3       12            8.3  2016    7/22/2016
# 36       4        1            7.7  2017     9/8/2017
# 37       4        2            9.1  2017     9/8/2017
# 38       4        3            8.2  2017     9/8/2017
# 39       4        4            7.8  2017     9/8/2017
# 40       4        5            8.1  2017     9/8/2017
# 41       4        6            8.9  2017     9/8/2017
# 42       4        7            8.1  2017     9/8/2017
# 43       4        8            7.6  2017     9/8/2017
# 44       4        9            8.7  2017     9/8/2017
# 45       4       10            8.2  2017     9/8/2017
# 46       4       11            9.7  2017     9/8/2017
# 47       4       12            8.7  2017     9/8/2017
# 48       5        1            8.0  2018    9/14/2018
# 49       5        2            9.0  2018    9/14/2018
# 50       5        3            8.1  2018    9/14/2018
# 51       5        4            8.2  2018    9/14/2018
# 52       5        5            8.5  2018    9/14/2018
# 53       5        6            9.8  2018    9/14/2018
# 54       5        7            8.9  2018    9/14/2018
# 55       5        8            8.5  2018    9/14/2018
# 56       5        9            8.3  2018    9/14/2018
# 57       5       10            9.0  2018    9/14/2018
# 58       5       11            9.5  2018    9/14/2018
# 59       5       12            9.1  2018    9/14/2018

# %% [markdown]
# ### Transform Netflix Stock DataFrame

# %%
# Create new dataFrame with specific columns
clean_netflix_df = netflix_df[["date","Month", "Day","year","open","high","low","close"]].copy()


# Rename the column headers
clean_netflix_df = clean_netflix_df.rename(columns={"date": "Date",
                                                    "Year": "Year",
                                                    "open": "Opening Price",
                                                    "high": "High Price",
                                                    "low": "Low Price",
                                                    "close": "Closing Price"})
# Display clean Netflix df
clean_netflix_df.head()
# Out:
#      Date  Month  Day  year  Opening Price  High Price  Low Price  \
# 0  1/2/14      1    2  2014        52.4014     52.5114    51.5429
# 1  1/3/14      1    3  2014        52.0000     52.4956    51.8429
# 2  1/6/14      1    6  2014        51.8900     52.0443    50.4757
# 3  1/7/14      1    7  2014        49.6843     49.6986    48.1529
# 4  1/8/14      1    8  2014        48.1043     49.4257    48.0743
#
#    Closing Price
# 0        51.8314
# 1        51.8714
# 2        51.3671
# 3        48.5000
# 4        48.7129

# %% [markdown]
# ### Create database connection

# %%
pg_user = 'postgres'
pg_password = 'postgres'
db_name = 'bojack_db'

connection_string = f"{pg_user}:{pg_password}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ### Confirm tables

# %%
engine.table_names()
# Out:
# ['clean_netflix_db']

# %% [markdown]
# ### Load Clean Netflix dataFrame into into bojack_db

# %%
clean_netflix_df.to_sql(name='clean_netflix_db', con=engine, if_exists='append', index=True)

# %% [markdown]
# ### Load Clean Bojack dataFrame into into bojack_db

# %%
clean_bojack_df.to_sql(name='clean_bojack_df', con=engine, if_exists='append', index=True)

# %% [markdown]
# ### Query Stock Prices from 1 week prior/after S1 release

# %%
s1_release = pd.read_sql_query('select * from clean_netflix_db where year = 2014 and "Month" = 8 and "Day" between 8 and 29', con=engine).head(11)
s1_release['Date'] = s1_release['Date'].astype(str)
s1_release = s1_release.set_index('Date')
s1_release
# Out:
#          index  Month  Day  year  Opening Price  High Price  Low Price  \
# Date
# 8/8/14     151      8    8  2014        64.3143     64.4243    63.1500
# 8/11/14    152      8   11  2014        64.1743     65.3786    64.1014
# 8/12/14    153      8   12  2014        64.4786     64.7143    63.3443
# 8/13/14    154      8   13  2014        64.0857     64.8879    63.8314
# 8/14/14    155      8   14  2014        64.6014     65.0000    64.0314
# 8/15/14    156      8   15  2014        64.4986     66.0000    64.0857
# 8/18/14    157      8   18  2014        66.0086     67.0714    65.8929
# 8/19/14    158      8   19  2014        66.7271     67.2143    66.0614
# 8/20/14    159      8   20  2014        66.7143     67.6786    66.3630
# 8/21/14    160      8   21  2014        67.3257     68.0214    66.8101
# 8/22/14    161      8   22  2014        67.2771     68.5071    67.1500
#
#          Closing Price
# Date
# 8/8/14         63.6929
# 8/11/14        64.5057
# 8/12/14        63.7729
# 8/13/14        64.5043
# 8/14/14        64.4100
# 8/15/14        65.5843
# 8/18/14        66.5714
# 8/19/14        66.8786
# 8/20/14        67.4557
# 8/21/14        67.4357
# 8/22/14        68.4557

# %% [markdown]
# ### Plot Season 1 Stock Data

# %%
# creating new plot for NFLX Price Before and After Season 1 Release
ax1 = s1_release['High Price'].plot()
# setting Y axis label
ax1.set_ylabel('Stock High Price')
# setting X axis label
ax1.set_xlabel('Date')
ax1.axvline(x=5,color='red')
# set plot title
ax1.set_title('$NFLX Before and After Season 1 Debut on 8/15/14')
# show figure and save as PNG for presentation
ax1.get_figure().savefig('../Resources/screenshots/S1_Release.png')

# %% [markdown]
# ### Query Stock Prices from 1 week prior/after S2 release

# %%
s2_release = pd.read_sql_query('select * from clean_netflix_db where year = 2015 and "Month" = 7 and "Day" between 10 and 24', con=engine).head(11)
s2_release['Date'] = s2_release['Date'].astype(str)
s2_release = s2_release.set_index('Date')
s2_release
# Out:
#          index  Month  Day  year  Opening Price  High Price  Low Price  \
# Date
# 7/10/15    382      7   10  2015        97.5229     98.5028    96.9000
# 7/13/15    383      7   13  2015        98.0986    102.3086    98.0788
# 7/14/15    384      7   14  2015       101.2714    101.6357    99.6529
# 7/15/15    385      7   15  2015        99.9700    100.7500    97.0500
# 7/16/15    386      7   16  2015       111.0200    116.4900   107.6800
# 7/17/15    387      7   17  2015       117.3400    117.8800   114.2400
# 7/20/15    388      7   20  2015       114.7000    114.7000   110.1400
# 7/21/15    389      7   21  2015       110.2100    113.7100   109.3200
# 7/22/15    390      7   22  2015       112.1400    113.8800   110.5608
# 7/23/15    391      7   23  2015       110.9100    112.1800   109.8400
# 7/24/15    392      7   24  2015       111.5500    111.6800   108.9000
#
#          Closing Price
# Date
# 7/10/15        97.2286
# 7/13/15       101.0871
# 7/14/15       100.3714
# 7/15/15        98.1300
# 7/16/15       115.8100
# 7/17/15       114.7700
# 7/20/15       110.5500
# 7/21/15       112.5100
# 7/22/15       111.5000
# 7/23/15       110.1000
# 7/24/15       109.3400

# %% [markdown]
# ### Plot Season 2 Stock Data

# %%
# creating new plot for NFLX Price Before and After Season 2 Release
ax2 = s2_release['High Price'].plot()
# setting Y axis label
ax2.set_ylabel('Stock High Price')
# setting X axis label
ax2.set_xlabel('Date')
ax2.axvline(x=5,color='red')
# set plot title
ax2.set_title('$NFLX Before and After Season 2 Debut on 7/17/15')
# show figure and save as PNG for presentation
ax2.get_figure().savefig('../Resources/screenshots/S2_Release.png')

# %% [markdown]
# ### Query Stock Prices from 1 week prior/after S3 release

# %%
s3_release = pd.read_sql_query('select * from clean_netflix_db where year = 2016 and "Month" = 7 and "Day" between 15 and 29', con=engine).head(11)
s3_release['Date'] = s3_release['Date'].astype(str)
s3_release = s3_release.set_index('Date')
s3_release
# Out:
#          index  Month  Day  year  Opening Price  High Price  Low Price  \
# Date
# 7/15/16    638      7   15  2016          98.52      98.700      97.41
# 7/18/16    639      7   18  2016          98.43      99.840      97.24
# 7/19/16    640      7   19  2016          85.43      86.750      84.50
# 7/20/16    641      7   20  2016          86.67      88.490      85.82
# 7/21/16    642      7   21  2016          88.30      88.380      85.21
# 7/22/16    643      7   22  2016          86.48      86.500      85.11
# 7/25/16    644      7   25  2016          85.73      87.870      85.01
# 7/26/16    645      7   26  2016          91.03      93.100      90.90
# 7/27/16    646      7   27  2016          91.50      92.060      90.10
# 7/28/16    647      7   28  2016          91.92      92.210      90.68
# 7/29/16    648      7   29  2016          91.19      91.749      90.59
#
#          Closing Price
# Date
# 7/15/16          98.39
# 7/18/16          98.81
# 7/19/16          85.84
# 7/20/16          87.91
# 7/21/16          85.99
# 7/22/16          85.89
# 7/25/16          87.66
# 7/26/16          91.41
# 7/27/16          92.04
# 7/28/16          91.65
# 7/29/16          91.25

# %% [markdown]
# ### Plot Season 3 Stock Data

# %%
# creating new plot for NFLX Price Before and After Season 3 Release
ax3 = s3_release['High Price'].plot()
# setting Y axis label
ax3.set_ylabel('Stock High Price')
# setting X axis label
ax3.set_xlabel('Date')
ax3.axvline(x=5,color='red', label="Release Date")
# set plot title
ax3.set_title('$NFLX Before and After Season 3 Debut on 7/22/16')
# show figure and save as PNG for presentation
ax3.get_figure().savefig('../Resources/screenshots/S3_Release.png')

# %% [markdown]
# ### Query Stock Prices from 1 week prior/after S4 release

# %%
s4_release = pd.read_sql_query('select * from clean_netflix_db where year = 2017 and "Month" = 9 and "Day" between 1 and 15', con=engine).head(11)
s4_release['Date'] = s4_release['Date'].astype(str)
s4_release = s4_release.set_index('Date')
s4_release
# Out:
#          index  Month  Day  year  Opening Price  High Price  Low Price  \
# Date
# 9/1/17     924      9    1  2017         175.55    176.4800   173.9200
# 9/5/17     925      9    5  2017         173.40    175.8800   172.4400
# 9/6/17     926      9    6  2017         175.25    179.4600   173.7300
# 9/7/17     927      9    7  2017         178.80    180.3500   177.1000
# 9/8/17     928      9    8  2017         178.45    180.3900   176.2500
# 9/11/17    929      9   11  2017         178.10    182.4700   178.0300
# 9/12/17    930      9   12  2017         182.55    185.3300   180.6435
# 9/13/17    931      9   13  2017         184.07    184.4995   182.5500
# 9/14/17    932      9   14  2017         183.25    185.2882   182.0700
# 9/15/17    933      9   15  2017         182.73    184.9300   181.4300
# 9/1/17     924      9    1  2017         175.55    176.4800   173.9200
#
#          Closing Price
# Date
# 9/1/17          174.74
# 9/5/17          174.52
# 9/6/17          179.25
# 9/7/17          179.00
# 9/8/17          176.42
# 9/11/17         181.74
# 9/12/17         185.15
# 9/13/17         183.64
# 9/14/17         182.63
# 9/15/17         182.35
# 9/1/17          174.74

# %% [markdown]
# ### Plot Season 4 Stock Data

# %%
# creating new plot for NFLX Price Before and After Season 4 Release
ax4 = s4_release['High Price'].plot()
# setting Y axis label
ax4.set_ylabel('Stock High Price')
# setting X axis label
ax4.set_xlabel('Date')
ax4.axvline(x=4,color='red', label="Release Date")
# set plot title
ax4.set_title('$NFLX Before and After Season 4 Debut on 9/8/17')
# show figure and save as PNG for presentation
ax4.get_figure().savefig('../Resources/screenshots/S4_Release.png')

# %% [markdown]
# ### Query Stock Prices from 1 week prior/after S5 release

# %%
s5_release = pd.read_sql_query('select * from clean_netflix_db where year = 2018 and "Month" = 9 and "Day" between 7 and 21', con=engine).head(11)
s5_release['Date'] = s5_release['Date'].astype(str)
s5_release = s5_release.set_index('Date')
s5_release
# Out:
#          index  Month  Day  year  Opening Price  High Price  Low Price  \
# Date
# 9/7/18    1179      9    7  2018         342.20      355.75   341.2500
# 9/10/18   1180      9   10  2018         352.27      352.50   343.0800
# 9/11/18   1181      9   11  2018         344.67      356.15   343.9001
# 9/12/18   1182      9   12  2018         359.08      370.43   356.2400
# 9/13/18   1183      9   13  2018         371.91      374.09   366.8400
# 9/14/18   1184      9   14  2018         368.55      371.09   363.4600
# 9/17/18   1185      9   17  2018         364.22      367.33   349.5700
# 9/18/18   1186      9   18  2018         353.67      368.15   351.5600
# 9/19/18   1187      9   19  2018         373.95      377.61   359.1700
# 9/20/18   1188      9   20  2018         370.26      370.26   363.1700
# 9/21/18   1189      9   21  2018         366.59      372.22   360.7400
#
#          Closing Price
# Date
# 9/7/18          348.68
# 9/10/18         348.41
# 9/11/18         355.93
# 9/12/18         369.95
# 9/13/18         368.15
# 9/14/18         364.56
# 9/17/18         350.35
# 9/18/18         367.65
# 9/19/18         366.96
# 9/20/18         365.36
# 9/21/18         361.19

# %% [markdown]
# ### Plot Season 5 Stock Data

# %%
# creating new plot for NFLX Price Before and After Season 4 Release
ax5 = s5_release['High Price'].plot()
# setting Y axis label
ax5.set_ylabel('Stock High Price')
# setting X axis label
ax5.set_xlabel('Date')
ax5.axvline(x=5,color='red', label="Release Date")
# set plot title
ax5.set_title('$NFLX Before and After Season 5 Debut on 9/15/18')
# show figure and save as PNG for presentation
ax5.get_figure().savefig('../Resources/screenshots/S5_Release.png')

# %% [markdown]
# ### Output table data to HTML

# %%
clean_bojack_df.to_html(classes="season5")
# Out:
# '<table border="1" class="dataframe season5">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>SEASON</th>\n      <th>EPISODE</th>\n      <th>RATING (IMDB)</th>\n      <th>YEAR</th>\n      <th>Release Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1</td>\n      <td>1</td>\n      <td>7.1</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>2</td>\n      <td>7.7</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>1</td>\n      <td>3</td>\n      <td>7.4</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>1</td>\n      <td>4</td>\n      <td>7.4</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>1</td>\n      <td>5</td>\n      <td>7.4</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>1</td>\n      <td>6</td>\n      <td>7.9</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>1</td>\n      <td>7</td>\n      <td>8.0</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>1</td>\n      <td>8</td>\n      <td>8.2</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>1</td>\n      <td>9</td>\n      <td>7.9</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>1</td>\n      <td>10</td>\n      <td>7.8</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>1</td>\n      <td>11</td>\n      <td>8.6</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>1</td>\n      <td>12</td>\n      <td>8.1</td>\n      <td>2014</td>\n      <td>8/22/2014</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>2</td>\n      <td>1</td>\n      <td>8.0</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>2</td>\n      <td>2</td>\n      <td>7.9</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>2</td>\n      <td>3</td>\n      <td>7.9</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>2</td>\n      <td>4</td>\n      <td>8.0</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>2</td>\n      <td>5</td>\n      <td>8.0</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>2</td>\n      <td>6</td>\n      <td>7.7</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>2</td>\n      <td>7</td>\n      <td>8.1</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>2</td>\n      <td>8</td>\n      <td>8.2</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>20</th>\n      <td>2</td>\n      <td>9</td>\n      <td>8.1</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>21</th>\n      <td>2</td>\n      <td>10</td>\n      <td>8.2</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>22</th>\n      <td>2</td>\n      <td>11</td>\n      <td>8.7</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>23</th>\n      <td>2</td>\n      <td>12</td>\n      <td>8.1</td>\n      <td>2015</td>\n      <td>7/17/2015</td>\n    </tr>\n    <tr>\n      <th>24</th>\n      <td>3</td>\n      <td>1</td>\n      <td>7.9</td>\n      <td>2016</td>\n      <td>7/22/2016</td>\n    </tr>\n    <tr>\n      <th>25</th>\n      <td>3</td>\n      <td>2</td>\n      <td>8.0</td>\n      <td>2016</td>\n      <td>7/22/2016</td>\n    </tr>\n    <tr>\n    ...
